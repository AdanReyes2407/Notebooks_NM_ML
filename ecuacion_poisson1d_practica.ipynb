# %% [markdown]
# # Poisson 1D: práctica guiada
#
# Problema estacionario:
#
# $$
# -u''(x)=f(x),\qquad x\in(0,1),\qquad u(0)=u(1)=0.
# $$
#
# Tomamos $f(x)=\pi^2\sin(\pi x)$, con solución exacta $u(x)=\sin(\pi x)$.

# %% [markdown]
# ## Forma discreta
#
# Con $h=1/(N+1)$ y nodos interiores:
#
# $$
# \frac{-u_{i+1}+2u_i-u_{i-1}}{h^2}=f_i.
# $$
#
# Para cada $N$, se resuelve un sistema lineal tridiagonal.

# %%
import numpy as np
import matplotlib.pyplot as plt


def exact_solution(x):
    return np.sin(np.pi * x)


def rhs_f(x):
    return (np.pi**2) * np.sin(np.pi * x)

# %% [markdown]
# ## TO DO A: construir A y b

# %%
def build_linear_system(n):
    # TO DO
    # Debe regresar x_in, h, A, b
    # Pista: A es tridiagonal con diag=2/h^2 y off=-1/h^2
    raise NotImplementedError("Completa build_linear_system")

# %% [markdown]
# ## TO DO B: resolver y calcular error

# %%
def solve_poisson(n):
    # TO DO
    # Debe regresar x_full, u_num, u_ex, h, err_l2, A
    # Pista: resuelve A u_in = b y luego agrega fronteras 0
    raise NotImplementedError("Completa solve_poisson")

# %% [markdown]
# ## TO DO C: barrido N=1,...,20

# %%
try:
    N_vals = np.arange(1, 21)
    errs = []
    for n in N_vals:
        _, _, _, _, err, _ = solve_poisson(n)
        errs.append(err)
    print("Error N=1:", errs[0])
    print("Error N=20:", errs[-1])
except NotImplementedError as e:
    print(e)

# %% [markdown]
# ## TO DO D: gráfica de convergencia
#
# Pista:
# - usa `N_vals` y `errs`,
# - grafica error L2 en función de N.

# %%
try:
    # TO DO
    # 1) grafica errs contra N_vals
    # 2) agrega título, ejes y rejilla
    raise NotImplementedError("Completa TO DO D")
except NotImplementedError as e:
    print(e)

# %% [markdown]
# ## TO DO E: matriz para N=5 y perfil para N=20
#
# Pista:
# - usa `build_linear_system(5)` para inspección matricial,
# - usa `solve_poisson(20)` para la comparación de perfiles.

# %%
try:
    # TO DO
    # Parte 1: imprime A y b para N=5
    # Parte 2: grafica numérica vs exacta para N=20
    raise NotImplementedError("Completa TO DO E")
except NotImplementedError as e:
    print(e)
