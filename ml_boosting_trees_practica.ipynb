# %% [markdown]
# # Boosting Trees (practica)
#
# Meta: estudiar la construccion secuencial del ensamble y su efecto sobre error de clasificacion.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, RocCurveDisplay
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.datasets import load_breast_cancer

# %%
import os
import sys
import subprocess
from pathlib import Path

REPO_NOTEBOOKS = "https://github.com/AdanReyes2407/Notebooks_NM_ML.git"


def is_colab():
    return "google.colab" in sys.modules


def ensure_repo_clone(repo_url=REPO_NOTEBOOKS, target=Path('/content/Notebooks_NM_ML')):
    if is_colab() and not target.exists():
        print(f"Clonando repositorio en {target} ...")
        subprocess.run(["git", "clone", repo_url, str(target)], check=True)


def resolve_data_dir():
    ensure_repo_clone()
    candidates = [
        Path('/content/Notebooks_NM_ML/Bases de datos'),
        Path.cwd() / 'Bases de datos',
        Path.cwd().parent / 'Bases de datos',
        Path('/content/Bases de datos'),
    ]
    for p in candidates:
        if p.exists():
            return p
    return None

# %% [markdown]
# ## TO DO 1: carga de datos
#
# Pistas:
# - intenta `spambase.data` en `DATA_DIR`,
# - respaldo: `load_breast_cancer(as_frame=True)`.

# %%
DATA_DIR = None  # TO DO

def load_dataset(data_dir):
    # TO DO
    raise NotImplementedError("Completa load_dataset")

# %% [markdown]
# ## TO DO 2: entrenar boosting base
#
# Configuracion sugerida:
# - n_estimators=300
# - learning_rate=0.05
# - max_depth=2

# %%
# TO DO
raise NotImplementedError("Completa entrenamiento base")

# %% [markdown]
# ## TO DO 3: evaluar accuracy y AUC

# %%
# TO DO
raise NotImplementedError("Completa evaluacion")

# %% [markdown]
# ## TO DO 4: curva ROC

# %%
# TO DO
raise NotImplementedError("Completa curva ROC")

# %% [markdown]
# ## TO DO 5: barrido de hiperparametros
#
# Pistas:
# - learning_rate en [0.01, 0.03, 0.05, 0.1]
# - n_estimators en [120, 250, 400, 600]

# %%
# TO DO
raise NotImplementedError("Completa barrido")
