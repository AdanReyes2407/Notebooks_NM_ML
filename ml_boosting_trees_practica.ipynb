# %% [markdown]
# # Boosting Trees
#
# Boosting agrega modelos d?biles de forma secuencial. Cada etapa pone ?nfasis en observaciones que a?n no quedan bien ajustadas.
#
# En esta pr?ctica se usa clasificaci?n binaria con `GradientBoostingClassifier`.

# %% [markdown]
# ## Convenci?n de trabajo
#
# - Este cuaderno est? pensado para ejecutarse en Colab o en entorno local.
# - Si existe una carpeta `Bases de datos`, puedes adaptar la carga de datos all?.
# - En este problema, los bloques **TO DO** marcan el trabajo que se espera completar.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, RocCurveDisplay

# %% [markdown]
# ## TO DO 1: cargar base y separar train/test

# %%
# TO DO
# Pista: usa load_breast_cancer(as_frame=True)
raise NotImplementedError("Completa la carga de datos")

# %% [markdown]
# ## TO DO 2: entrenar boosting base

# %%
# TO DO
# Pista: n_estimators=250, learning_rate=0.05, max_depth=2
raise NotImplementedError("Completa el entrenamiento base")

# %% [markdown]
# ## TO DO 3: m?tricas accuracy y AUC

# %%
# TO DO
# Pista: para AUC usa predict_proba(... )[:,1]
raise NotImplementedError("Completa evaluaci?n")

# %% [markdown]
# ## TO DO 4: curva ROC

# %%
# TO DO
# Pista: RocCurveDisplay.from_predictions(y_test, y_prob)
raise NotImplementedError("Completa curva ROC")

# %% [markdown]
# ## TO DO 5: interacci?n learning_rate y n_estimators

# %%
# TO DO
# Pista: prueba combinaciones de learning_rate en [0.01,0.03,0.05,0.1]
# y n_estimators en [120, 250, 500]
raise NotImplementedError("Completa barrido de hiperpar?metros")
