# %% [markdown]
# # Redes neuronales con Keras (practica)

# %% [markdown]
# Objetivo: construir una red densa para clasificacion de digitos,
# analizar curvas de entrenamiento y discutir sobreajuste.

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## TO DO 1: cargar y preprocesar MNIST

# %%
# TO DO
# - keras.datasets.mnist.load_data()
# - normalizar a [0,1]
# - aplanar a 784
raise NotImplementedError("Completa preproceso")

# %% [markdown]
# ## TO DO 2: definir y compilar la red

# %%
# TO DO
# arquitectura sugerida: 256-128-10
raise NotImplementedError("Completa modelo")

# %% [markdown]
# ## TO DO 3: entrenamiento con validacion

# %%
# TO DO
# epochs=12, batch_size=128, validation_split=0.15
raise NotImplementedError("Completa entrenamiento")

# %% [markdown]
# ## TO DO 4: evaluar en test

# %%
# TO DO
raise NotImplementedError("Completa evaluacion")

# %% [markdown]
# ## TO DO 5: curvas de aprendizaje

# %%
# TO DO
raise NotImplementedError("Completa graficas")
