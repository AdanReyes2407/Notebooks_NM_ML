# %% [markdown]
# # Introducci?n a Keras: clasificaci?n de im?genes
#
# Se construye una red densa para clasificar d?gitos manuscritos (MNIST).
#
# Objetivo del cuaderno:
#
# 1. preparar los datos,
# 2. definir arquitectura,
# 3. entrenar y evaluar,
# 4. estudiar se?ales de sobreajuste.

# %% [markdown]
# ## Convenci?n de trabajo
#
# - Este cuaderno est? pensado para ejecutarse en Colab o en entorno local.
# - Si existe una carpeta `Bases de datos`, puedes adaptar la carga de datos all?.
# - En este problema, los bloques **TO DO** marcan el trabajo que se espera completar.

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## TO DO 1: cargar y preprocesar MNIST

# %%
# Pista:
# - (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# - normaliza a [0,1]
# - aplana a vectores de 784

# TO DO
raise NotImplementedError("Completa carga y preproceso")

# %% [markdown]
# ## TO DO 2: definir modelo en Keras

# %%
# Pista:
# - capa entrada (784,)
# - Dense(256, relu), Dense(128, relu), Dense(10, softmax)
# - compilar con adam + sparse_categorical_crossentropy

# TO DO
raise NotImplementedError("Completa definici?n del modelo")

# %% [markdown]
# ## TO DO 3: entrenamiento con validaci?n

# %%
# Pista:
# - usa epochs=10 y batch_size=128
# - validation_split=0.15

# TO DO
raise NotImplementedError("Completa entrenamiento")

# %% [markdown]
# ## TO DO 4: evaluaci?n en test

# %%
# TO DO
# Pista: model.evaluate(x_test, y_test, verbose=0)
raise NotImplementedError("Completa evaluaci?n")

# %% [markdown]
# ## TO DO 5: curvas de entrenamiento

# %%
# TO DO
# Pista:
# - grafica loss y val_loss
# - grafica accuracy y val_accuracy
raise NotImplementedError("Completa gr?ficas de entrenamiento")
