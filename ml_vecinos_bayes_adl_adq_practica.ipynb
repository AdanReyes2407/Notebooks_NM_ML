# %% [markdown]
# # Clasificaci?n supervisada: ADL, ADQ, Bayes ingenuo y k vecinos
#
# Se comparan cuatro enfoques cl?sicos para clasificaci?n multiclase.
#
# Modelos:
#
# - **ADL (LDA)**: frontera lineal con covarianza compartida.
# - **ADQ (QDA)**: frontera cuadr?tica con covarianzas por clase.
# - **Bayes ingenuo gaussiano**: independencia condicional de caracter?sticas.
# - **k vecinos**: decisi?n por proximidad en espacio de atributos.
#
# Base del ejercicio: conjunto *Wine* de `sklearn`.

# %% [markdown]
# ## Convenci?n de trabajo
#
# - Este cuaderno est? pensado para ejecutarse en Colab o en entorno local.
# - Si existe una carpeta `Bases de datos`, puedes adaptar la carga de datos all?.
# - En este problema, los bloques **TO DO** marcan el trabajo que se espera completar.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# %% [markdown]
# ## TO DO 1: carga y partici?n

# %%
# Pista:
# 1) usa load_wine(as_frame=True)
# 2) separa X, y
# 3) aplica train_test_split con stratify=y

# TO DO
raise NotImplementedError("Completa la carga y partici?n de datos")

# %% [markdown]
# ## TO DO 2: estandarizaci?n

# %%
# Pista:
# - ajusta StandardScaler con X_train
# - transforma X_train y X_test

# TO DO
raise NotImplementedError("Completa la estandarizaci?n")

# %% [markdown]
# ## TO DO 3: entrenamiento de los cuatro modelos

# %%
# Pista:
# - define un diccionario con los modelos
# - LDA(), QDA(), GaussianNB(), KNeighborsClassifier(n_neighbors=7)

# TO DO
raise NotImplementedError("Completa el entrenamiento")

# %% [markdown]
# ## TO DO 4: tabla comparativa de desempe?o

# %%
# Pista:
# - para cada modelo calcula accuracy en test
# - arma un DataFrame y ord?nalo de mayor a menor

# TO DO
raise NotImplementedError("Completa la comparaci?n")

# %% [markdown]
# ## TO DO 5: matriz de confusi?n del mejor modelo

# %%
# Pista:
# - identifica el mejor modelo seg?n accuracy
# - usa ConfusionMatrixDisplay.from_predictions

# TO DO
raise NotImplementedError("Completa la matriz de confusi?n")

# %% [markdown]
# ## TO DO 6: elecci?n de k en vecinos

# %%
# Pista:
# - recorre k de 1 a 20
# - guarda accuracy test
# - grafica accuracy vs k

# TO DO
raise NotImplementedError("Completa el barrido de k")
