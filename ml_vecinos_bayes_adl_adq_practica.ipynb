# %% [markdown]
# # ADL, ADQ, Bayes ingenuo y k vecinos (practica)
#
# Objetivo: comparar cuatro modelos clasicos de clasificacion sobre una base tabular,
# medir su desempeno fuera de muestra y justificar diferencias de error.

# %% [markdown]
# ## Esquema de trabajo
#
# 1. resolver carpeta de datos en Colab/local,
# 2. cargar base principal (vertebral) o respaldo,
# 3. entrenar ADL, ADQ, Bayes ingenuo y k-NN,
# 4. analizar matriz de confusion y metricas por clase,
# 5. estudiar sensibilidad del hiperparametro k.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay
from sklearn.datasets import load_wine

# %%
import os
import sys
import subprocess
from pathlib import Path

REPO_NOTEBOOKS = "https://github.com/AdanReyes2407/Notebooks_NM_ML.git"


def is_colab():
    return "google.colab" in sys.modules


def ensure_repo_clone(repo_url=REPO_NOTEBOOKS, target=Path('/content/Notebooks_NM_ML')):
    if is_colab() and not target.exists():
        print(f"Clonando repositorio en {target} ...")
        subprocess.run(["git", "clone", repo_url, str(target)], check=True)


def resolve_data_dir():
    ensure_repo_clone()
    candidates = [
        Path('/content/Notebooks_NM_ML/Bases de datos'),
        Path.cwd() / 'Bases de datos',
        Path.cwd().parent / 'Bases de datos',
        Path('/content/Bases de datos'),
    ]
    for p in candidates:
        if p.exists():
            return p
    return None

# %% [markdown]
# ## TO DO 1: cargar base de datos
#
# Pistas:
# - busca `column_2C.dat` dentro de `DATA_DIR`,
# - si no aparece, usa `load_wine(as_frame=True)` como respaldo,
# - devuelve `X`, `y` y `fuente`.

# %%
DATA_DIR = None  # TO DO: resolver con resolve_data_dir()

def load_dataset(data_dir):
    # TO DO
    # caso principal: column_2C.dat
    # respaldo: wine de sklearn
    raise NotImplementedError("Completa load_dataset")

# %% [markdown]
# ## TO DO 2: particion y estandarizacion
#
# Pistas:
# - train_test_split estratificado,
# - StandardScaler ajustado solo con train,
# - transformar train y test.

# %%
# TO DO
# X, y, fuente = load_dataset(DATA_DIR)
# X_train, X_test, y_train, y_test = ...
# scaler = StandardScaler(); X_train_s = ...; X_test_s = ...
raise NotImplementedError("Completa particion y escalado")

# %% [markdown]
# ## TO DO 3: entrenamiento de modelos
#
# Modelos:
# - ADL (LDA)
# - ADQ (QDA)
# - Bayes ingenuo gaussiano
# - k vecinos con k=7

# %%
# TO DO
# define diccionario de modelos y ajusta cada uno
raise NotImplementedError("Completa entrenamiento de modelos")

# %% [markdown]
# ## TO DO 4: tabla comparativa y matriz de confusion del mejor modelo

# %%
# TO DO
# calcular accuracy por modelo, ordenar y mostrar matriz de confusion del mejor
raise NotImplementedError("Completa comparativa final")

# %% [markdown]
# ## TO DO 5: barrido de k en k-NN
#
# Pistas:
# - recorre k de 1 a 25,
# - calcula accuracy en test,
# - grafica curva accuracy vs k.

# %%
# TO DO
raise NotImplementedError("Completa barrido de k")
